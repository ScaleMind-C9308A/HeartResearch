# %%
import matplotlib.pyplot as plt
from glob import glob
import os
import json
import pandas as pd
import seaborn as sns
import numpy as np
from scipy.ndimage import gaussian_filter

# %%
print(os.getcwd())
# Out:
# /home/linhpika/git/HeartResearch/Experiment

# %%
main_data_dir = os.getcwd() + "/Approach"

# %%
# done
heatmap_focal_best_dir_81 = main_data_dir + "/EfficientB0/Focal_Loss/run_efficientB0_heatmap_gamma0.3_new_lr0.001"
heatmap_focal_best_dir_91 = main_data_dir + "/EfficientB0/Focal_Loss/run_efficientB0_heatmap_gamma0.3_lr0.001_2500_9-1"


resnet_focal_best_dir_81 = main_data_dir + "/Model_signal/Focal_Loss/run_resnet_gamma0.3_lr0.001_8-1"
resnet_focal_best_dir_91 = main_data_dir + "/Model_signal/Focal_Loss/run_resnet_gamma0.3_lr0.001_9-1"

# done
DNN_1D_dir_81 = main_data_dir + "/Model_signal/Other_model/run_1D_DNN_lr0.001_8-1"
DNN_1D_dir_91 = main_data_dir + "/Model_signal/Other_model/run_1D_DNN_lr0.0005"

# done
Augment_dir_81 = main_data_dir + "/Model_signal/Other_model/run_augment_lr0.001_8-1"
Augment_dir_91 = main_data_dir + "/Model_signal/Other_model/run_augment_lr0.001"

# done
AE_dir_81 = main_data_dir + "/Model_signal/Other_model/run_AE_lr0.0005"
AE_dir_91 = main_data_dir + "/Model_signal/Other_model/run_AE_lr0.001_9-1"

#done
resnet_dir_81 = main_data_dir + "/Model_signal/Other_model/run_ResNet_lr0.001_8-1"
resnet_dir_91 = main_data_dir + "/Model_signal/Other_model/run_ResNet_lr0.001_9-1"

#done
heatmap_dir_81 = main_data_dir + "/EfficientB0/Focal_Loss/run_efficientB0_heatmap_only_lr0.001_2500_8-1"
heatmap_dir_91 = main_data_dir + "/EfficientB0/Focal_Loss/run_efficientB0_heatmap_only_lr0.001_2500_9-1"


effiv2_dir = main_data_dir + "/EfficientB0/Focal_Loss/run_efficientv2_heatmap_gamma0.3_new_lr0.001_9-1"

resnext_dir = main_data_dir + "/EfficientB0/Focal_Loss/run_resnext_heatmap_gamma0.3_new_lr0.001_9-1" 

regnet_dir = main_data_dir + "/EfficientB0/Focal_Loss/run_regnet_heatmap_gamma0.3_new_lr0.001_9-1"

# %%
acc_loss_dir = "/save_acc_loss_json"

# Done
heatmap_focal_best_file_81 = heatmap_focal_best_dir_81 + acc_loss_dir + "/acc_loss_01-16-2024 - 22-09-04.json"
heatmap_focal_best_file_91 = heatmap_focal_best_dir_91 + acc_loss_dir + "/acc_loss_01-17-2024 - 19-32-11.json"

# done
resnet_focal_best_file_81 = resnet_focal_best_dir_81 + acc_loss_dir + "/acc_loss_01-17-2024 - 20-27-16.json"
resnet_focal_best_file_91 = resnet_focal_best_dir_91 + acc_loss_dir + "/acc_loss_01-18-2024 - 00-42-38.json"

# done
DNN_1D_file_81 = DNN_1D_dir_81 + acc_loss_dir + "/acc_loss_01-17-2024 - 23-58-16.json"
DNN_1D_file_91 = DNN_1D_dir_91 + acc_loss_dir + "/acc_loss_01-16-2024 - 14-16-47.json"

# done
Augment_file_81 = Augment_dir_81 + acc_loss_dir + "/acc_loss_01-18-2024 - 09-44-25.json"
Augment_file_91 = Augment_dir_91 + acc_loss_dir + "/acc_loss_01-16-2024 - 19-37-38.json"

# Done
AE_file_81 = AE_dir_81 + acc_loss_dir + "/acc_loss_01-16-2024 - 14-19-05.json"
AE_file_91 = AE_dir_91 + acc_loss_dir + "/acc_loss_01-17-2024 - 18-03-42.json"

# Done
resnet_file_81 = resnet_dir_81 + acc_loss_dir + "/acc_loss_01-17-2024 - 21-11-23.json"
resnet_file_91 = resnet_dir_91 + acc_loss_dir + "/acc_loss_01-17-2024 - 21-18-21.json"

#done
heatmap_file_81 = heatmap_dir_81 + acc_loss_dir + "/acc_loss_01-17-2024 - 23-07-17.json"
heatmap_file_91 = heatmap_dir_91 + acc_loss_dir + "/acc_loss_01-17-2024 - 23-12-09.json"


effiv2_file = effiv2_dir + acc_loss_dir + "/acc_loss_01-18-2024 - 13-18-56.json"
resnext_file = resnext_dir + acc_loss_dir + "/acc_loss_01-18-2024 - 14-23-10.json"
regnet_file = regnet_dir + acc_loss_dir + "/acc_loss_01-18-2024 - 14-29-13.json"

# %%
f_effiv2 = open(effiv2_file)
data_effiv2 = json.load(f_effiv2)

f_resnext = open(resnext_file)
data_resnext = json.load(f_resnext)

f_regnet = open(regnet_file)
data_regnet = json.load(f_regnet)

f_heatmap_focal_81 = open(heatmap_focal_best_file_81)
data_heatmap_focal_81 = json.load(f_heatmap_focal_81)
f_heatmap_focal_91 = open(heatmap_focal_best_file_91)
data_heatmap_focal_91 = json.load(f_heatmap_focal_91)

f_resnet_focal_81 = open(resnet_focal_best_file_81)
data_resnet_focal_81 = json.load(f_resnet_focal_81)
f_resnet_focal_91 = open(resnet_focal_best_file_91)
data_resnet_focal_91 = json.load(f_resnet_focal_91)

f_DNN_1D_81 = open(DNN_1D_file_81)
data_DNN_1D_81 = json.load(f_DNN_1D_81)
f_DNN_1D_91 = open(DNN_1D_file_81)
data_DNN_1D_91 = json.load(f_DNN_1D_91)

f_augment_81 = open(Augment_file_81)
data_augment_81 = json.load(f_augment_81)
f_augment_91 = open(Augment_file_91)
data_augment_91 = json.load(f_augment_91)

f_AE_81 = open(AE_file_81)
data_AE_81 = json.load(f_AE_81)
f_AE_91 = open(AE_file_91)
data_AE_91 = json.load(f_AE_91)

f_resnet_81 = open(resnet_file_81)
data_resnet_81 = json.load(f_resnet_81)
f_resnet_91 = open(resnet_file_91)
data_resnet_91 = json.load(f_resnet_91)

f_heatmap_81 = open(heatmap_file_81)
data_heatmap_81 = json.load(f_heatmap_81)
f_heatmap_91 = open(heatmap_file_91)
data_heatmap_91 = json.load(f_heatmap_91)

# %%
epoch = 150
df_acc_81 = pd.DataFrame({'ICWA + Focal loss (gamma = 0.3)': data_heatmap_focal_81['valid']['acc'],
                          'ResNet + Focal loss (gamma = 0.3)': data_resnet_focal_81['valid']['acc'],
                          '1D DNN': data_DNN_1D_81['valid']['acc'],
                          'AE': data_AE_81['valid']['acc'],
                          'ResNet + Augmentation': data_augment_81['valid']['acc'],
                          'ICWA': data_heatmap_81['valid']['acc'],
                          'ResNet': data_resnet_81['valid']['acc']
                  })
df_loss_81 = pd.DataFrame({'ICWA + Focal loss (gamma = 0.3)': data_heatmap_focal_81['valid']['loss'],
                          'ResNet + Focal loss (gamma = 0.3)': data_resnet_focal_81['valid']['loss'],
                          '1D DNN': data_DNN_1D_81['valid']['loss'],
                          'AE': data_AE_81['valid']['loss'],
                          'ResNet + Augmentation': data_augment_81['valid']['loss'],
                          'ICWA': data_heatmap_81['valid']['loss'],
                          'ResNet': data_resnet_81['valid']['loss']
                          })

df_acc_91 = pd.DataFrame({'ICWA + Focal loss (gamma = 0.3)': data_heatmap_focal_91['valid']['acc'],
                          'ResNet + Focal loss (gamma = 0.3)': data_resnet_focal_91['valid']['acc'],
                          '1D DNN': data_DNN_1D_91['valid']['acc'],
                          'AE': data_AE_91['valid']['acc'],
                          'ResNet + Augmentation': data_augment_91['valid']['acc'],
                          'ICWA': data_heatmap_91['valid']['acc'],
                          'ResNet': data_resnet_91['valid']['acc']
                  })
df_loss_91 = pd.DataFrame({'ICWA + Focal loss (gamma = 0.3)': data_heatmap_focal_91['valid']['loss'],
                          'ResNet + Focal loss (gamma = 0.3)': data_resnet_focal_91['valid']['loss'],
                          '1D DNN': data_DNN_1D_91['valid']['loss'],
                          'AE': data_AE_91['valid']['loss'],
                          'ResNet + Augmentation': data_augment_91['valid']['loss'],
                          'ICWA': data_heatmap_91['valid']['loss'],
                          'ResNet': data_resnet_91['valid']['loss']
                          })

df_Models =  pd.DataFrame({'ICWA': data_heatmap_focal_91['valid']['acc'],
                          'ResNet': data_resnet_focal_91['valid']['acc'],
                          'ResNeXt': data_resnext['valid']['acc'],
                          'RegNet': data_regnet['valid']['acc'],
                          'EfficientNetV2': data_effiv2['valid']['acc']
                          })

# %%
save_dir = "/home/linhpika/git/HeartResearch/Experiment/Approach"
save_file_model = save_dir + "/ablation_models.pdf"

sns.lineplot(data=df_Models['ICWA'], color = 'red', label = "ICWA-SE")
sns.lineplot(data=df_Models['ResNet'], color = 'teal', label = "ResNet")
sns.lineplot(data=df_Models['ResNeXt'], color = 'steelblue', label = 'ResNeXt' )
sns.lineplot(data=df_Models['RegNet'], color = 'pink', label = 'RegNet')
sns.lineplot(data=df_Models['EfficientNetV2'], color = 'mediumaquamarine', label = 'EfficientNetV2')

plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.65, 0.85])
plt.xlim([120, 150])
plt.grid(True)
plt.legend()
plt.savefig(save_file_model, format = 'pdf', dpi = 300, bbox_inches='tight')

# %%
# palette = sns.color_palette("mako_r", 7)
# save_dir = "/home/linhpika/git/HeartResearch/Experiment/Approach"
save_file = save_dir + "/Benchmark_81.pdf"
palette=sns.color_palette("rocket")
sns.lineplot(data=df_acc_81['ICWA + Focal loss (gamma = 0.3)'], color = 'red', label = "ICWA-SE + Focal loss (gamma = 0.3)")
sns.lineplot(data=df_acc_81['ResNet + Focal loss (gamma = 0.3)'], color = 'teal', label = "ResNet + Focal loss (gamma = 0.3)")
sns.lineplot(data=df_acc_81['1D DNN'], color = 'steelblue', label = '1D DNN' )
sns.lineplot(data=df_acc_81['AE'], color = 'pink', label = 'AE')
sns.lineplot(data=df_acc_81['ResNet + Augmentation'], color = 'mediumaquamarine', label = 'ResNet + Augmentation')
sns.lineplot(data=df_acc_81['ICWA'], color = 'mediumorchid', label = 'ICWA-SE')
sns.lineplot(data=df_acc_81['ResNet'], color = 'orange', label = 'ResNet')

plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.grid(True)
plt.legend()
plt.savefig(save_file, format = 'pdf', dpi = 300, bbox_inches='tight')

# %%
# palette = sns.color_palette("mako_r", 7)
save_dir = "/home/linhpika/git/HeartResearch/Experiment/Approach"
save_file = save_dir + "/Benchmark_91.pdf"
palette=sns.color_palette("rocket")
sns.lineplot(data=df_acc_91['ICWA + Focal loss (gamma = 0.3)'], color = 'red', label = "ICWA-SE + Focal loss (gamma = 0.3)")
sns.lineplot(data=df_acc_91['ResNet + Focal loss (gamma = 0.3)'], color = 'teal', label = "ResNet + Focal loss (gamma = 0.3)")
sns.lineplot(data=df_acc_91['1D DNN'], color = 'steelblue', label = '1D DNN' )
sns.lineplot(data=df_acc_91['AE'], color = 'pink', label = 'AE')
sns.lineplot(data=df_acc_91['ResNet + Augmentation'], color = 'mediumaquamarine', label = 'ResNet + Augmentation')
sns.lineplot(data=df_acc_91['ICWA'], color = 'mediumorchid', label = 'ICWA-SE')
sns.lineplot(data=df_acc_91['ResNet'], color = 'orange', label = 'ResNet')

plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.grid(True)
plt.legend()
plt.savefig(save_file, format = 'pdf', dpi = 300, bbox_inches='tight')

# %%
# palette = sns.color_palette("mako_r", 7)
# sns.lineplot(data=df_loss_81,palette=palette )
# plt.xlabel('Epoch')
# plt.ylabel('Loss')
# plt.grid(True)

# %%
"run_efficientB0_heatmap_gamma0.1_new_lr0.001_2500_9-1"
# Out:
# 'run_efficientB0_heatmap_gamma0.1_new_lr0.001_2500_9-1'

# %%
heatmap_focal_filename_list = ["acc_loss_01-18-2024 - 05-58-58.json",
                              "acc_loss_01-17-2024 - 23-10-05.json",
                               "acc_loss_01-18-2024 - 05-58-56.json",
                               "acc_loss_01-18-2024 - 06-00-24.json",
                               "acc_loss_01-17-2024 - 19-32-16.json",
                               "acc_loss_01-18-2024 - 07-20-20.json",
                               "acc_loss_01-18-2024 - 07-23-29.json",
                               "acc_loss_01-18-2024 - 07-23-30.json",
                               "acc_loss_01-18-2024 - 07-22-04.json",
                               "acc_loss_01-18-2024 - 08-20-35.json"
                              ]
    
#     heatmap_focal_{gamma}_81_dir = main_data_dir + f"/EfficientB0/Focal_Loss/run_efficientB0_heatmap_gamma{gamma}_new_lr0.001"
heatmap_focal_c1_91_dir = main_data_dir + f"/EfficientB0/Focal_Loss/run_efficientB0_heatmap_gamma0.1_new_lr0.001_2500_9-1"
heatmap_focal_c1_91_file= heatmap_focal_c1_91_dir + acc_loss_dir + f"/{heatmap_focal_filename_list[0]}"
f_heatmap_focal_c1_91= open(heatmap_focal_c1_91_file)
data_heatmap_focal_c1_91 = json.load(f_heatmap_focal_c1_91)

heatmap_focal_c3_91_dir = main_data_dir + f"/EfficientB0/Focal_Loss/run_efficientB0_heatmap_gamma0.3_new_lr0.001_2500_9-1"
heatmap_focal_c3_91_file= heatmap_focal_c3_91_dir + acc_loss_dir + f"/{heatmap_focal_filename_list[1]}"
f_heatmap_focal_c3_91= open(heatmap_focal_c3_91_file)
data_heatmap_focal_c3_91 = json.load(f_heatmap_focal_c3_91)

heatmap_focal_c5_91_dir = main_data_dir + f"/EfficientB0/Focal_Loss/run_efficientB0_heatmap_gamma0.5_new_lr0.001_2500_9-1"
heatmap_focal_c5_91_file= heatmap_focal_c5_91_dir + acc_loss_dir + f"/{heatmap_focal_filename_list[2]}"
f_heatmap_focal_c5_91= open(heatmap_focal_c5_91_file)
data_heatmap_focal_c5_91 = json.load(f_heatmap_focal_c5_91)

heatmap_focal_c7_91_dir = main_data_dir + f"/EfficientB0/Focal_Loss/run_efficientB0_heatmap_gamma0.7_new_lr0.001_2500_9-1"
heatmap_focal_c7_91_file= heatmap_focal_c7_91_dir + acc_loss_dir + f"/{heatmap_focal_filename_list[3]}"
f_heatmap_focal_c7_91= open(heatmap_focal_c7_91_file)
data_heatmap_focal_c7_91 = json.load(f_heatmap_focal_c7_91)

heatmap_focal_c9_91_dir = main_data_dir + f"/EfficientB0/Focal_Loss/run_efficientB0_heatmap_gamma0.9_new_lr0.001_2500_9-1"
heatmap_focal_c9_91_file= heatmap_focal_c9_91_dir + acc_loss_dir + f"/{heatmap_focal_filename_list[4]}"
f_heatmap_focal_c9_91= open(heatmap_focal_c9_91_file)
data_heatmap_focal_c9_91 = json.load(f_heatmap_focal_c9_91)

heatmap_focal_1_91_dir = main_data_dir + f"/EfficientB0/Focal_Loss/run_efficientB0_heatmap_gamma1_new_lr0.001_2500_9-1"
heatmap_focal_1_91_file= heatmap_focal_1_91_dir + acc_loss_dir + f"/{heatmap_focal_filename_list[5]}"
f_heatmap_focal_1_91= open(heatmap_focal_1_91_file)
data_heatmap_focal_1_91 = json.load(f_heatmap_focal_1_91)

heatmap_focal_2_91_dir = main_data_dir + f"/EfficientB0/Focal_Loss/run_efficientB0_heatmap_gamma2_new_lr0.001_2500_9-1"
heatmap_focal_2_91_file= heatmap_focal_2_91_dir + acc_loss_dir + f"/{heatmap_focal_filename_list[6]}"
f_heatmap_focal_2_91= open(heatmap_focal_2_91_file)
data_heatmap_focal_2_91 = json.load(f_heatmap_focal_2_91)

heatmap_focal_3_91_dir = main_data_dir + f"/EfficientB0/Focal_Loss/run_efficientB0_heatmap_gamma3_new_lr0.001_2500_9-1"
heatmap_focal_3_91_file= heatmap_focal_3_91_dir + acc_loss_dir + f"/{heatmap_focal_filename_list[7]}"
f_heatmap_focal_3_91= open(heatmap_focal_3_91_file)
data_heatmap_focal_3_91 = json.load(f_heatmap_focal_3_91)

heatmap_focal_4_91_dir = main_data_dir + f"/EfficientB0/Focal_Loss/run_efficientB0_heatmap_gamma4_new_lr0.001_2500_9-1"
heatmap_focal_4_91_file= heatmap_focal_4_91_dir + acc_loss_dir + f"/{heatmap_focal_filename_list[8]}"
f_heatmap_focal_4_91= open(heatmap_focal_4_91_file)
data_heatmap_focal_4_91 = json.load(f_heatmap_focal_4_91)

heatmap_focal_5_91_dir = main_data_dir + f"/EfficientB0/Focal_Loss/run_efficientB0_heatmap_gamma5_new_lr0.001_2500_9-1"
heatmap_focal_5_91_file= heatmap_focal_5_91_dir + acc_loss_dir + f"/{heatmap_focal_filename_list[9]}"
f_heatmap_focal_5_91= open(heatmap_focal_5_91_file)
data_heatmap_focal_5_91 = json.load(f_heatmap_focal_5_91)

df_acc_heatmapfocal_91 = pd.DataFrame({'gamma = 0.1': data_heatmap_focal_c1_91['valid']['acc'],
                                       'gamma = 0.3': data_heatmap_focal_c3_91['valid']['acc'],
                                       'gamma = 0.5': data_heatmap_focal_c5_91['valid']['acc'],
                                       'gamma = 0.7': data_heatmap_focal_c7_91['valid']['acc'],
                                       'gamma = 0.9': data_heatmap_focal_c9_91['valid']['acc'],
                                       'gamma = 1': data_heatmap_focal_1_91['valid']['acc'],
                                       'gamma = 2': data_heatmap_focal_2_91['valid']['acc'],
                                       'gamma = 3': data_heatmap_focal_3_91['valid']['acc'],
                                       'gamma = 4': data_heatmap_focal_4_91['valid']['acc'],
                                       'gamma = 5': data_heatmap_focal_5_91['valid']['acc'],
                  })

# %%
heatmap_focal_filename_list_81 = ["acc_loss_01-16-2024 - 19-04-16.json",
                              "acc_loss_01-16-2024 - 22-09-04.json",
                               "acc_loss_01-16-2024 - 17-55-33.json",
                                  "acc_loss_01-16-2024 - 17-53-01.json",
                                  "acc_loss_01-16-2024 - 22-05-49.json",
                                  "acc_loss_01-15-2024 - 02-22-41.json",
                                  "acc_loss_01-15-2024 - 09-02-02.json",
                                  "acc_loss_01-15-2024 - 08-51-49.json",
                                  "acc_loss_01-15-2024 - 09-36-11.json",
                                  "acc_loss_01-15-2024 - 09-38-42.json"
                               
                              ]
    
heatmap_focal_c1_81_dir = main_data_dir + f"/EfficientB0/Focal_Loss/run_efficientB0_heatmap_gamma0.1_lr0.001"
heatmap_focal_c1_81_file= heatmap_focal_c1_81_dir + acc_loss_dir + f"/{heatmap_focal_filename_list_81[0]}"
f_heatmap_focal_c1_81= open(heatmap_focal_c1_81_file)
data_heatmap_focal_c1_81 = json.load(f_heatmap_focal_c1_81)

heatmap_focal_c3_81_dir = main_data_dir + f"/EfficientB0/Focal_Loss/run_efficientB0_heatmap_gamma0.3_new_lr0.001"
heatmap_focal_c3_81_file= heatmap_focal_c3_81_dir + acc_loss_dir + f"/{heatmap_focal_filename_list_81[1]}"
f_heatmap_focal_c3_81= open(heatmap_focal_c3_81_file)
data_heatmap_focal_c3_81 = json.load(f_heatmap_focal_c3_81)

heatmap_focal_c5_81_dir = main_data_dir + f"/EfficientB0/Focal_Loss/run_efficientB0_heatmap_gamma0.5_lr0.001"
heatmap_focal_c5_81_file= heatmap_focal_c5_81_dir + acc_loss_dir + f"/{heatmap_focal_filename_list_81[2]}"
f_heatmap_focal_c5_81= open(heatmap_focal_c5_81_file)
data_heatmap_focal_c5_81 = json.load(f_heatmap_focal_c5_81)

heatmap_focal_c7_81_dir = main_data_dir + f"/EfficientB0/Focal_Loss/run_efficientB0_heatmap_gamma0.7_lr0.001"
heatmap_focal_c7_81_file= heatmap_focal_c7_81_dir + acc_loss_dir + f"/{heatmap_focal_filename_list_81[3]}"
f_heatmap_focal_c7_81= open(heatmap_focal_c7_81_file)
data_heatmap_focal_c7_81 = json.load(f_heatmap_focal_c7_81)

heatmap_focal_c9_81_dir = main_data_dir + f"/EfficientB0/Focal_Loss/run_efficientB0_heatmap_gamma0.9_new_lr0.001"
heatmap_focal_c9_81_file= heatmap_focal_c9_81_dir + acc_loss_dir + f"/{heatmap_focal_filename_list_81[4]}"
f_heatmap_focal_c9_81= open(heatmap_focal_c9_81_file)
data_heatmap_focal_c9_81 = json.load(f_heatmap_focal_c9_81)

heatmap_focal_1_81_dir = main_data_dir + f"/EfficientB0/Focal_Loss/run_efficientB0_heatmap_gamma1_lr0.0005"
heatmap_focal_1_81_file= heatmap_focal_1_81_dir + acc_loss_dir + f"/{heatmap_focal_filename_list_81[5]}"
f_heatmap_focal_1_81= open(heatmap_focal_1_81_file)
data_heatmap_focal_1_81 = json.load(f_heatmap_focal_1_81)

heatmap_focal_2_81_dir = main_data_dir + f"/EfficientB0/Focal_Loss/run_efficientB0_heatmap_gamma2_lr0.0005"
heatmap_focal_2_81_file= heatmap_focal_2_81_dir + acc_loss_dir + f"/{heatmap_focal_filename_list_81[6]}"
f_heatmap_focal_2_81= open(heatmap_focal_2_81_file)
data_heatmap_focal_2_81 = json.load(f_heatmap_focal_2_81)

heatmap_focal_3_81_dir = main_data_dir + f"/EfficientB0/Focal_Loss/run_efficientB0_heatmap_gamma3_lr0.0005"
heatmap_focal_3_81_file= heatmap_focal_3_81_dir + acc_loss_dir + f"/{heatmap_focal_filename_list_81[7]}"
f_heatmap_focal_3_81= open(heatmap_focal_3_81_file)
data_heatmap_focal_3_81 = json.load(f_heatmap_focal_3_81)

heatmap_focal_4_81_dir = main_data_dir + f"/EfficientB0/Focal_Loss/run_efficientB0_heatmap_gamma4_lr0.0005"
heatmap_focal_4_81_file= heatmap_focal_4_81_dir + acc_loss_dir + f"/{heatmap_focal_filename_list_81[8]}"
f_heatmap_focal_4_81= open(heatmap_focal_4_81_file)
data_heatmap_focal_4_81 = json.load(f_heatmap_focal_4_81)

heatmap_focal_5_81_dir = main_data_dir + f"/EfficientB0/Focal_Loss/run_efficientB0_heatmap_gamma5_lr0.0005"
heatmap_focal_5_81_file= heatmap_focal_5_81_dir + acc_loss_dir + f"/{heatmap_focal_filename_list_81[9]}"
f_heatmap_focal_5_81= open(heatmap_focal_5_81_file)
data_heatmap_focal_5_81 = json.load(f_heatmap_focal_5_81)

df_acc_heatmapfocal_81 = pd.DataFrame({'gamma = 0.1': data_heatmap_focal_c1_81['valid']['acc'],
                                       'gamma = 0.3': data_heatmap_focal_c3_81['valid']['acc'],
                                       'gamma = 0.5': data_heatmap_focal_c5_81['valid']['acc'],
                                       'gamma = 0.7': data_heatmap_focal_c7_81['valid']['acc'],
                                       'gamma = 0.9': data_heatmap_focal_c9_81['valid']['acc'],
                                       'gamma = 1': data_heatmap_focal_1_81['valid']['acc'],
                                       'gamma = 2': data_heatmap_focal_2_81['valid']['acc'],
                                       'gamma = 3': data_heatmap_focal_3_81['valid']['acc'],
                                       'gamma = 4': data_heatmap_focal_4_81['valid']['acc'],
                                       'gamma = 5': data_heatmap_focal_5_81['valid']['acc'],
                  })

# %%
resnet_focal_filename_list_81 = ["acc_loss_01-15-2024 - 10-11-32.json",
                                 "acc_loss_01-17-2024 - 20-27-16.json",
                                 "acc_loss_01-15-2024 - 11-20-26.json",
                                 "acc_loss_01-15-2024 - 11-34-25.json",
                                 "acc_loss_01-15-2024 - 11-35-37.json",
                                 "acc_loss_01-15-2024 - 12-20-27.json",
                                 "acc_loss_01-15-2024 - 13-02-32.json",
                                 "acc_loss_01-15-2024 - 13-05-09.json",
                                 "acc_loss_01-15-2024 - 13-30-52.json",
                                 "acc_loss_01-15-2024 - 14-29-03.json"
                                ]
    
resnet_focal_c1_81_dir = main_data_dir + "/Model_signal/Focal_Loss/run_resnet_gamma0.1_lr0.0005"
resnet_focal_c1_81_file= resnet_focal_c1_81_dir + acc_loss_dir + f"/{resnet_focal_filename_list_81[0]}"
f_resnet_focal_c1_81= open(resnet_focal_c1_81_file)
data_resnet_focal_c1_81 = json.load(f_resnet_focal_c1_81)

resnet_focal_c3_81_dir = main_data_dir + "/Model_signal/Focal_Loss/run_resnet_gamma0.3_lr0.001_8-1"
resnet_focal_c3_81_file= resnet_focal_c3_81_dir + acc_loss_dir + f"/{resnet_focal_filename_list_81[1]}"
f_resnet_focal_c3_81= open(resnet_focal_c3_81_file)
data_resnet_focal_c3_81 = json.load(f_resnet_focal_c3_81)

resnet_focal_c5_81_dir = main_data_dir + "/Model_signal/Focal_Loss/run_resnet_gamma0.5_lr0.0005"
resnet_focal_c5_81_file= resnet_focal_c5_81_dir + acc_loss_dir + f"/{resnet_focal_filename_list_81[2]}"
f_resnet_focal_c5_81= open(resnet_focal_c5_81_file)
data_resnet_focal_c5_81 = json.load(f_resnet_focal_c5_81)

resnet_focal_c7_81_dir = main_data_dir + "/Model_signal/Focal_Loss/run_resnet_gamma0.7_lr0.0005"
resnet_focal_c7_81_file= resnet_focal_c7_81_dir + acc_loss_dir + f"/{resnet_focal_filename_list_81[3]}"
f_resnet_focal_c7_81= open(resnet_focal_c7_81_file)
data_resnet_focal_c7_81 = json.load(f_resnet_focal_c7_81)

resnet_focal_c9_81_dir = main_data_dir + "/Model_signal/Focal_Loss/run_resnet_gamma0.9_lr0.0005"
resnet_focal_c9_81_file= resnet_focal_c9_81_dir + acc_loss_dir + f"/{resnet_focal_filename_list_81[4]}"
f_resnet_focal_c9_81= open(resnet_focal_c9_81_file)
data_resnet_focal_c9_81 = json.load(f_resnet_focal_c9_81)

resnet_focal_1_81_dir = main_data_dir + "/Model_signal/Focal_Loss/run_resnet_gamma1_lr0.0005"
resnet_focal_1_81_file= resnet_focal_1_81_dir + acc_loss_dir + f"/{resnet_focal_filename_list_81[5]}"
f_resnet_focal_1_81= open(resnet_focal_1_81_file)
data_resnet_focal_1_81 = json.load(f_resnet_focal_1_81)

resnet_focal_2_81_dir = main_data_dir + "/Model_signal/Focal_Loss/run_resnet_gamma2_lr0.0005"
resnet_focal_2_81_file= resnet_focal_2_81_dir + acc_loss_dir + f"/{resnet_focal_filename_list_81[6]}"
f_resnet_focal_2_81= open(resnet_focal_2_81_file)
data_resnet_focal_2_81 = json.load(f_resnet_focal_2_81)

resnet_focal_3_81_dir = main_data_dir + "/Model_signal/Focal_Loss/run_resnet_gamma3_lr0.0005"
resnet_focal_3_81_file= resnet_focal_3_81_dir + acc_loss_dir + f"/{resnet_focal_filename_list_81[7]}"
f_resnet_focal_3_81= open(resnet_focal_3_81_file)
data_resnet_focal_3_81 = json.load(f_resnet_focal_3_81)

resnet_focal_4_81_dir = main_data_dir + "/Model_signal/Focal_Loss/run_resnet_gamma4_lr0.0005"
resnet_focal_4_81_file= resnet_focal_4_81_dir + acc_loss_dir + f"/{resnet_focal_filename_list_81[8]}"
f_resnet_focal_4_81= open(resnet_focal_4_81_file)
data_resnet_focal_4_81 = json.load(f_resnet_focal_4_81)

resnet_focal_5_81_dir = main_data_dir + "/Model_signal/Focal_Loss/run_resnet_gamma5_lr0.0005"
resnet_focal_5_81_file= resnet_focal_5_81_dir + acc_loss_dir + f"/{resnet_focal_filename_list_81[9]}"
f_resnet_focal_5_81= open(resnet_focal_5_81_file)
data_resnet_focal_5_81 = json.load(f_resnet_focal_5_81)



df_acc_resnetfocal_81 = pd.DataFrame({'gamma = 0.1': data_resnet_focal_c1_81['valid']['acc'],
                                       'gamma = 0.3': data_resnet_focal_c3_81['valid']['acc'],
                                       'gamma = 0.5': data_resnet_focal_c5_81['valid']['acc'],
                                       'gamma = 0.7': data_resnet_focal_c7_81['valid']['acc'],
                                       'gamma = 0.9': data_resnet_focal_c9_81['valid']['acc'],
                                       'gamma = 1': data_resnet_focal_1_81['valid']['acc'],
                                       'gamma = 2': data_resnet_focal_2_81['valid']['acc'],
                                       'gamma = 3': data_resnet_focal_3_81['valid']['acc'],
                                       'gamma = 4': data_resnet_focal_4_81['valid']['acc'],
                                       'gamma = 5': data_resnet_focal_5_81['valid']['acc'],
                  })

# %%
resnet_focal_filename_list_91 = ["acc_loss_01-18-2024 - 08-15-36.json",
                                 "acc_loss_01-18-2024 - 00-42-38.json",
                                 "acc_loss_01-18-2024 - 08-17-44.json",
                                 "acc_loss_01-18-2024 - 09-37-46.json",
                                 "acc_loss_01-18-2024 - 09-47-58.json",
                                 "acc_loss_01-18-2024 - 11-05-52.json",
                                 "acc_loss_01-18-2024 - 10-55-26.json",
                                 "acc_loss_01-18-2024 - 11-58-36.json",
                                 "acc_loss_01-18-2024 - 12-08-24.json",
                                 
                                 
                                ]
    
resnet_focal_c1_91_dir = main_data_dir + "/Model_signal/Focal_Loss/run_resnet_gamma0.1_lr0.001_9-1"
resnet_focal_c1_91_file= resnet_focal_c1_91_dir + acc_loss_dir + f"/{resnet_focal_filename_list_91[0]}"
f_resnet_focal_c1_91= open(resnet_focal_c1_91_file)
data_resnet_focal_c1_91 = json.load(f_resnet_focal_c1_91)

resnet_focal_c3_91_dir = main_data_dir + "/Model_signal/Focal_Loss/run_resnet_gamma0.3_lr0.001_9-1"
resnet_focal_c3_91_file= resnet_focal_c3_91_dir + acc_loss_dir + f"/{resnet_focal_filename_list_91[1]}"
f_resnet_focal_c3_91= open(resnet_focal_c3_91_file)
data_resnet_focal_c3_91 = json.load(f_resnet_focal_c3_91)

resnet_focal_c5_91_dir = main_data_dir + "/Model_signal/Focal_Loss/run_resnet_gamma0.5_lr0.001_9-1"
resnet_focal_c5_91_file= resnet_focal_c5_91_dir + acc_loss_dir + f"/{resnet_focal_filename_list_91[2]}"
f_resnet_focal_c5_91= open(resnet_focal_c5_91_file)
data_resnet_focal_c5_91 = json.load(f_resnet_focal_c5_91)

resnet_focal_c7_91_dir = main_data_dir + "/Model_signal/Focal_Loss/run_resnet_gamma0.7_lr0.001_9-1"
resnet_focal_c7_91_file= resnet_focal_c7_91_dir + acc_loss_dir + f"/{resnet_focal_filename_list_91[3]}"
f_resnet_focal_c7_91= open(resnet_focal_c7_91_file)
data_resnet_focal_c7_91 = json.load(f_resnet_focal_c7_91)

resnet_focal_c9_91_dir = main_data_dir + "/Model_signal/Focal_Loss/run_resnet_gamma0.9_lr0.001_9-1"
resnet_focal_c9_91_file= resnet_focal_c9_91_dir + acc_loss_dir + f"/{resnet_focal_filename_list_91[4]}"
f_resnet_focal_c9_91= open(resnet_focal_c9_91_file)
data_resnet_focal_c9_91 = json.load(f_resnet_focal_c9_91)

resnet_focal_1_91_dir = main_data_dir + "/Model_signal/Focal_Loss/run_resnet_gamma1_lr0.001_9-1"
resnet_focal_1_91_file= resnet_focal_1_91_dir + acc_loss_dir + f"/{resnet_focal_filename_list_91[5]}"
f_resnet_focal_1_91= open(resnet_focal_1_91_file)
data_resnet_focal_1_91 = json.load(f_resnet_focal_1_91)

resnet_focal_2_91_dir = main_data_dir + "/Model_signal/Focal_Loss/run_resnet_gamma2_lr0.001_9-1"
resnet_focal_2_91_file= resnet_focal_2_91_dir + acc_loss_dir + f"/{resnet_focal_filename_list_91[6]}"
f_resnet_focal_2_91= open(resnet_focal_2_91_file)
data_resnet_focal_2_91 = json.load(f_resnet_focal_2_91)

resnet_focal_3_91_dir = main_data_dir + "/Model_signal/Focal_Loss/run_resnet_gamma3_lr0.001_9-1"
resnet_focal_3_91_file= resnet_focal_3_91_dir + acc_loss_dir + f"/{resnet_focal_filename_list_91[7]}"
f_resnet_focal_3_91= open(resnet_focal_3_91_file)
data_resnet_focal_3_91 = json.load(f_resnet_focal_3_91)

resnet_focal_4_91_dir = main_data_dir + "/Model_signal/Focal_Loss/run_resnet_gamma4_lr0.001_9-1"
resnet_focal_4_91_file= resnet_focal_4_91_dir + acc_loss_dir + f"/{resnet_focal_filename_list_91[8]}"
f_resnet_focal_4_91= open(resnet_focal_4_91_file)
data_resnet_focal_4_91 = json.load(f_resnet_focal_4_91)

# resnet_focal_5_91_dir = main_data_dir + "/Model_signal/Focal_Loss/run_resnet_gamma5_lr0.0005"
# resnet_focal_5_91_file= resnet_focal_5_91_dir + acc_loss_dir + f"/{resnet_focal_filename_list_91[9]}"
# f_resnet_focal_5_91= open(resnet_focal_5_91_file)
# data_resnet_focal_5_91 = json.load(f_resnet_focal_5_91)



df_acc_resnetfocal_91 = pd.DataFrame({'gamma = 0.1': data_resnet_focal_c1_91['valid']['acc'],
                                       'gamma = 0.3': data_resnet_focal_c3_91['valid']['acc'],
                                       'gamma = 0.5': data_resnet_focal_c5_91['valid']['acc'],
                                       'gamma = 0.7': data_resnet_focal_c7_91['valid']['acc'],
                                       'gamma = 0.9': data_resnet_focal_c9_91['valid']['acc'],
                                       'gamma = 1': data_resnet_focal_1_91['valid']['acc'],
                                       'gamma = 2': data_resnet_focal_2_91['valid']['acc'],
                                       'gamma = 3': data_resnet_focal_3_91['valid']['acc'],
                                       'gamma = 4': data_resnet_focal_4_91['valid']['acc'],
                                       'gamma = 5': data_resnet_focal_5_81['valid']['acc'],
                  })

test = gaussian_filter(df_acc_resnetfocal_91['gamma = 0.1'], sigma=2)

# %%
save_file_91_gammaresnet = save_dir + "/GammaResnet_91.pdf"

sns.lineplot(data=gaussian_filter(df_acc_resnetfocal_91['gamma = 0.1'], sigma=2), color = 'seagreen', linestyle='solid', label = "gamma = 0.1")
sns.lineplot(data=gaussian_filter(df_acc_resnetfocal_91['gamma = 0.3'], sigma=2), color = 'red', linestyle='solid', label = "gamma = 0.3")
sns.lineplot(data=gaussian_filter(df_acc_resnetfocal_91['gamma = 0.5'], sigma=2), color = 'mediumaquamarine', linestyle='solid', label = "gamma = 0.5")
sns.lineplot(data=gaussian_filter(df_acc_resnetfocal_91['gamma = 0.7'], sigma=2), color = 'lightblue', linestyle='solid', label = "gamma = 0.7")
sns.lineplot(data=gaussian_filter(df_acc_resnetfocal_91['gamma = 0.9'], sigma=2), color = 'plum', linestyle='solid', label = "gamma = 0.9")
sns.lineplot(data=gaussian_filter(df_acc_resnetfocal_91['gamma = 1'], sigma=2), color = 'mediumpurple', linestyle='solid', label = "gamma = 1")
sns.lineplot(data=gaussian_filter(df_acc_resnetfocal_91['gamma = 2'], sigma=2), color = 'tan', linestyle='solid', label = "gamma = 2")
sns.lineplot(data=gaussian_filter(df_acc_resnetfocal_91['gamma = 3'], sigma=2), color = 'paleturquoise', linestyle='solid', label = "gamma = 3")
sns.lineplot(data=gaussian_filter(df_acc_resnetfocal_91['gamma = 4'], sigma=2), color = 'cornflowerblue', linestyle='solid', label = "gamma = 4")
sns.lineplot(data=gaussian_filter(df_acc_resnetfocal_91['gamma = 5'], sigma=2), color = 'darkgray', linestyle='solid', label = "gamma = 5")

plt.xlabel('Epoch')
plt.ylabel('Accuracy')
# plt.ylim([0.67, 0.81])
# plt.xlim([120, 150])
plt.grid(True)
plt.legend(loc = "lower right", ncols = 2)
plt.savefig(save_file_91_gammaresnet, format = 'pdf', dpi = 300, bbox_inches='tight')

# %%
save_file_81_gammaresnet = save_dir + "/GammaResnet_81.pdf"

sns.lineplot(data=gaussian_filter(df_acc_resnetfocal_81['gamma = 0.1'], sigma=2), color = 'seagreen', linestyle='solid', label = "gamma = 0.1")
sns.lineplot(data=gaussian_filter(df_acc_resnetfocal_81['gamma = 0.3'], sigma=2), color = 'red', linestyle='solid', label = "gamma = 0.3")
sns.lineplot(data=gaussian_filter(df_acc_resnetfocal_81['gamma = 0.5'], sigma=2), color = 'mediumaquamarine', linestyle='solid', label = "gamma = 0.5")
sns.lineplot(data=gaussian_filter(df_acc_resnetfocal_81['gamma = 0.7'], sigma=2), color = 'lightblue', linestyle='solid', label = "gamma = 0.7")
sns.lineplot(data=gaussian_filter(df_acc_resnetfocal_81['gamma = 0.9'], sigma=2), color = 'plum', linestyle='solid', label = "gamma = 0.9")
sns.lineplot(data=gaussian_filter(df_acc_resnetfocal_81['gamma = 1'], sigma=2), color = 'mediumpurple', linestyle='solid', label = "gamma = 1")
sns.lineplot(data=gaussian_filter(df_acc_resnetfocal_81['gamma = 2'], sigma=2), color = 'tan', linestyle='solid', label = "gamma = 2")
sns.lineplot(data=gaussian_filter(df_acc_resnetfocal_81['gamma = 3'], sigma=2), color = 'paleturquoise', linestyle='solid', label = "gamma = 3")
sns.lineplot(data=gaussian_filter(df_acc_resnetfocal_81['gamma = 4'], sigma=2), color = 'cornflowerblue', linestyle='solid', label = "gamma = 4")
sns.lineplot(data=gaussian_filter(df_acc_resnetfocal_81['gamma = 5'], sigma=2), color = 'darkgray', linestyle='solid', label = "gamma = 5")

plt.xlabel('Epoch')
plt.ylabel('Accuracy')
# plt.ylim([0.67, 0.81])
# plt.xlim([120, 150])
plt.grid(True)
plt.legend(loc = "lower right", ncols = 2)
plt.savefig(save_file_81_gammaresnet, format = 'pdf', dpi = 300, bbox_inches='tight')

# %%
save_file_91 = save_dir + "/Gamma_91.pdf"

sns.lineplot(data=df_acc_heatmapfocal_91['gamma = 0.1'], color = 'seagreen', linestyle='solid', label = "gamma = 0.1")
sns.lineplot(data=df_acc_heatmapfocal_91['gamma = 0.3'], color = 'red', linestyle='solid', label = "gamma = 0.3")
sns.lineplot(data=df_acc_heatmapfocal_91['gamma = 0.5'], color = 'mediumaquamarine', linestyle='solid', label = "gamma = 0.5")
sns.lineplot(data=df_acc_heatmapfocal_91['gamma = 0.7'], color = 'lightblue', linestyle='solid', label = "gamma = 0.7")
sns.lineplot(data=df_acc_heatmapfocal_91['gamma = 0.9'], color = 'plum', linestyle='solid', label = "gamma = 0.9")
sns.lineplot(data=df_acc_heatmapfocal_91['gamma = 1'], color = 'mediumpurple', linestyle='solid', label = "gamma = 1")
sns.lineplot(data=df_acc_heatmapfocal_91['gamma = 2'], color = 'tan', linestyle='solid', label = "gamma = 2")
sns.lineplot(data=df_acc_heatmapfocal_91['gamma = 3'], color = 'paleturquoise', linestyle='solid', label = "gamma = 3")
sns.lineplot(data=df_acc_heatmapfocal_91['gamma = 4'], color = 'cornflowerblue', linestyle='solid', label = "gamma = 4")
sns.lineplot(data=df_acc_heatmapfocal_91['gamma = 5'], color = 'darkgray', linestyle='solid', label = "gamma = 5")

plt.xlabel('Epoch')
plt.ylabel('Accuracy')
# plt.ylim([0.76, 0.83])
# plt.xlim([120, 150])
plt.grid(True)
plt.legend(loc = "lower right", ncols = 2)
plt.savefig(save_file_91, format = 'pdf', dpi = 300, bbox_inches='tight')

# %%
save_file_81 = save_dir + "/Gamma_81.pdf"
sns.lineplot(data=df_acc_heatmapfocal_81['gamma = 0.1'], color = 'seagreen', linestyle='solid', label = "gamma = 0.1")
sns.lineplot(data=df_acc_heatmapfocal_81['gamma = 0.3'], color = 'red', linestyle='solid', label = "gamma = 0.3")
sns.lineplot(data=df_acc_heatmapfocal_81['gamma = 0.5'], color = 'mediumaquamarine', linestyle='solid', label = "gamma = 0.5")
sns.lineplot(data=df_acc_heatmapfocal_81['gamma = 0.7'], color = 'lightblue', linestyle='solid', label = "gamma = 0.7")
sns.lineplot(data=df_acc_heatmapfocal_81['gamma = 0.9'], color = 'plum', linestyle='solid', label = "gamma = 0.9")
sns.lineplot(data=df_acc_heatmapfocal_81['gamma = 1'], color = 'mediumpurple', linestyle='solid', label = "gamma = 1")
sns.lineplot(data=df_acc_heatmapfocal_81['gamma = 2'], color = 'tan', linestyle='solid', label = "gamma = 2")
sns.lineplot(data=df_acc_heatmapfocal_81['gamma = 3'], color = 'paleturquoise', linestyle='solid', label = "gamma = 3")
sns.lineplot(data=df_acc_heatmapfocal_81['gamma = 4'], color = 'cornflowerblue', linestyle='solid', label = "gamma = 4")
sns.lineplot(data=df_acc_heatmapfocal_81['gamma = 5'], color = 'darkgray', linestyle='solid', label = "gamma = 5")

plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.75, 0.845])
plt.xlim([120, 150])
plt.grid(True)
plt.legend(loc = "lower right", ncols = 2)
plt.savefig(save_file_81, format = 'pdf', dpi = 300, bbox_inches='tight')
